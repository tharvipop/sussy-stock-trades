# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %%
# df = pd.read_csv('data/cleaned_transactions.csv')
# df.head()

# %%
df = pd.read_csv('data/no_missing_transactions.csv')
df.head()
# Out:
#    disclosure_year      disclosure_date     transaction_date  owner ticker  \
# 0             2021  2021-10-04 00:00:00  2021-09-27 00:00:00  joint     BP
# 1             2021  2021-10-04 00:00:00  2021-09-13 00:00:00  joint    XOM
# 2             2021  2021-10-04 00:00:00  2021-09-10 00:00:00  joint   ILPT
# 3             2021  2021-10-04 00:00:00  2021-09-28 00:00:00  joint     PM
# 4             2021  2021-10-04 00:00:00  2021-09-17 00:00:00   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount     representative district  \
# 0   $1,001 - $15,000      Virginia Foxx     NC05
# ...

# %%
new_df = df.copy()
new_df['is_CA'] = (new_df.state == 'CA').replace({True: 'cali', False: 'non_cali'})
new_df
# Out:
#        disclosure_year      disclosure_date     transaction_date    owner  \
# 0                 2021  2021-10-04 00:00:00  2021-09-27 00:00:00    joint
# 1                 2021  2021-10-04 00:00:00  2021-09-13 00:00:00    joint
# 2                 2021  2021-10-04 00:00:00  2021-09-10 00:00:00    joint
# 3                 2021  2021-10-04 00:00:00  2021-09-28 00:00:00    joint
# 4                 2021  2021-10-04 00:00:00  2021-09-17 00:00:00     self
# ...                ...                  ...                  ...      ...
# 14192             2020  2020-06-10 00:00:00  2020-04-09 00:00:00  missing
# 14193             2020  2020-06-10 00:00:00  2020-04-09 00:00:00  missing
# 14194             2020  2020-06-10 00:00:00  2020-03-13 00:00:00  missing
# 14195             2020  2020-06-10 00:00:00  2020-03-13 00:00:00  missing
# 14196             2020  2020-06-10 00:00:00  2020-03-13 00:00:00  missing
#
#       ticker                                  asset_description          type  \
# ...

# %%
new_df.groupby('is_CA')['prediction'].mean().to_frame()
