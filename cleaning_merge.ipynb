# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/all_transactions.csv')
reps_party = pd.read_csv('data/reps_party.csv')

# %%
df.head(2)
# Out:
#    disclosure_year disclosure_date transaction_date  owner ticker  \
# 0             2021      10/04/2021       2021-09-27  joint     BP
# 1             2021      10/04/2021       2021-09-13  joint    XOM
#
#          asset_description      type            amount      representative  \
# 0                   BP plc  purchase  $1,001 - $15,000  Hon. Virginia Foxx
# 1  Exxon Mobil Corporation  purchase  $1,001 - $15,000  Hon. Virginia Foxx
#
#   district                                           ptr_link  \
# 0     NC05  https://disclosures-clerk.house.gov/public_dis...
# 1     NC05  https://disclosures-clerk.house.gov/public_dis...
#
#    cap_gains_over_200_usd
# 0                   False
# 1                   False

# %%
reps_party['State'] = reps_party['District'].str.split().str[0]
reps_party = reps_party[['Member', 'Party.1', 'State']]

# %%
reps_party['Member'].str.contains("Neal").sum()
reps_party.loc[reps_party['Member'].str.contains('Rogers')]
# Out:
#           Member     Party.1     State
# 2    Mike Rogers  Republican   Alabama
# 171   Hal Rogers  Republican  Kentucky

# %%
df['representative'] = df['representative'].str.replace('Hon. ', '')
df['representative'] = df['representative'].str.replace('Mr. ', '')
df
# df['representative'].to_csv('data/just_reps.csv')
# Out:
# /var/folders/3k/d13l9xy576xd1j71sdj55ttc0000gn/T/ipykernel_17773/4277307071.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['representative'] = df['representative'].str.replace('Hon. ', '')
# /var/folders/3k/d13l9xy576xd1j71sdj55ttc0000gn/T/ipykernel_17773/4277307071.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['representative'] = df['representative'].str.replace('Mr. ', '')
#        disclosure_year disclosure_date transaction_date  owner ticker  \
# 0                 2021      10/04/2021       2021-09-27  joint     BP
# 1                 2021      10/04/2021       2021-09-13  joint    XOM
# 2                 2021      10/04/2021       2021-09-10  joint   ILPT
# 3                 2021      10/04/2021       2021-09-28  joint     PM
# 4                 2021      10/04/2021       2021-09-17   self    BLK
# ...
