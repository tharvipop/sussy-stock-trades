# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/all_transactions.csv')

# %%
df.head(5)
party_reps
# Out:
#          Party                               Name           Handle  \
# 0     Democrat                US Rep. Darren Soto    RepDarrenSoto
# 1     Democrat                   Rep. Jacky Rosen    RepJackyRosen
# 2     Democrat               US Rep. Al Lawson Jr    RepAlLawsonJr
# 3     Democrat                  Adriano Espaillat     RepEspaillat
# 4     Democrat                US Rep. Darren Soto    RepDarrenSoto
# 5     Democrat                   Rep. Jacky Rosen    RepJackyRosen
# 6     Democrat               US Rep. Al Lawson Jr    RepAlLawsonJr
# 7     Democrat                  Adriano Espaillat     RepEspaillat
# 8     Democrat               Rep. Blunt Rochester    RepBRochester
# 9     Democrat                Nanette D. Barragán      RepBarragan
# 10    Democrat                         Tom Suozzi     RepTomSuozzi
# 11    Democrat                     Rep. Ro Khanna      RepRoKhanna
# 12    Democrat               Rep. Ruben J. Kihuen        RepKihuen
# ...

# %%
party_reps = party_reps[['Name', 'Party']]

# %%
party_reps['Name'] = party_reps['Name'].str.replace('US Rep.','')
party_reps['Name'] = party_reps['Name'].str.replace('Rep.','')
party_reps
# Out:
# /var/folders/3k/d13l9xy576xd1j71sdj55ttc0000gn/T/ipykernel_17773/3591453315.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   party_reps['Name'] = party_reps['Name'].str.replace('US Rep.','')
# /var/folders/3k/d13l9xy576xd1j71sdj55ttc0000gn/T/ipykernel_17773/3591453315.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   party_reps['Name'] = party_reps['Name'].str.replace('Rep.','')
#                                  Name       Party
# 0                         Darren Soto    Democrat
# 1                         Jacky Rosen    Democrat
# 2                        Al Lawson Jr    Democrat
# 3                   Adriano Espaillat    Democrat
# 4                         Darren Soto    Democrat
# 5                         Jacky Rosen    Democrat
# 6                        Al Lawson Jr    Democrat
# 7                   Adriano Espaillat    Democrat
# ...
