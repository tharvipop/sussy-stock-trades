# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/cleaned_all_transactions.csv').iloc[:, 1:]
df.head()
# Out:
#    disclosure_year disclosure_date transaction_date  owner ticker  \
# 0             2021      2021-10-04       2021-09-27  joint     BP
# 1             2021      2021-10-04       2021-09-13  joint    XOM
# 2             2021      2021-10-04       2021-09-10  joint   ILPT
# 3             2021      2021-10-04       2021-09-28  joint     PM
# 4             2021      2021-10-04       2021-09-17   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount     representative district  \
# 0   $1,001 - $15,000      Virginia Foxx     NC05
# 1   $1,001 - $15,000      Virginia Foxx     NC05
# ...

# %% [markdown]
# ### **All the nulls:**

# %%
df[df['asset_description'].isnull()]
# Out:
#        disclosure_year disclosure_date transaction_date  owner ticker  \
# 797               2021      2021-02-10       2021-01-12  joint    BLL
# 3787              2021      2021-03-28       2021-03-16  joint   CELO
# 12119             2021      2021-03-18       2021-02-16    NaN   URGO
# 12120             2021      2021-03-18       2021-02-18    NaN   URGO
#
#       asset_description          type             amount representative  \
# 797                 NaN  sale_partial   $1,001 - $15,000      Susie Lee
# 3787                NaN      purchase   $1,001 - $15,000  Mark Dr Green
# 12119               NaN      purchase  $15,001 - $50,000     Brian Mast
# 12120               NaN      purchase   $1,001 - $15,000     Brian Mast
#
#       district                                           ptr_link  \
# 797       NV03  https://disclosures-clerk.house.gov/public_dis...
# 3787      TN07  https://disclosures-clerk.house.gov/public_dis...
# ...

# %%
df[df['owner'].isnull()]
# Out:
#        disclosure_year disclosure_date transaction_date owner ticker  \
# 6                 2021      2021-12-01       2021-11-30   NaN  KPLTW
# 7                 2021      2021-12-01       2021-11-18   NaN    AMD
# 8                 2021      2021-12-01       2021-11-18   NaN   AAPL
# 9                 2021      2021-12-01       2021-11-24   NaN   MSFT
# 10                2021      2021-12-01       2021-11-24   NaN     MS
# ...                ...             ...              ...   ...    ...
# 14174             2020      2020-06-10       2020-05-18   NaN   MSFT
# 14183             2020      2020-06-10       2020-05-18   NaN     BX
# 14199             2020      2020-06-10       2020-03-13   NaN    BMY
# 14200             2020      2020-06-10       2020-03-13   NaN    LLY
# 14201             2020      2020-06-10       2020-03-13   NaN    DIS
#
#                        asset_description       type                 amount  \
# ...

# %%
df[df['transaction_date'].isnull()]
# Out:
#        disclosure_year disclosure_date transaction_date  owner ticker  \
# 2314              2021      2021-07-13              NaN  joint   SBUX
# 4024              2021      2021-09-28              NaN  joint    GXO
# 7599              2021      2021-12-17              NaN    NaN      A
# 10742             2021      2021-07-16              NaN  joint     KR
# 10743             2021      2021-07-16              NaN    NaN     KR
#
#                                        asset_description          type  \
# 2314                               Starbucks Corporation     sale_full
# 4024   GXO Logistics. Note: This was a spinoff from X...      exchange
# 7599                            Agilent Technologies Inc     sale_full
# 10742                                     Kroger Company  sale_partial
# 10743                                     Kroger Company  sale_partial
#
#                     amount     representative district  \
# 2314      $1,001 - $15,000          Susie Lee     NV03
# ...

# %%
df[df['ticker'].isnull()]
# Out:
# Empty DataFrame
# Columns: [disclosure_year, disclosure_date, transaction_date, owner, ticker, asset_description, type, amount, representative, district, ptr_link, cap_gains_over_200_usd, state, amount_cleaned]
# Index: []

# %%
df[df['ticker'] == "--"]
# Out:
#        disclosure_year disclosure_date transaction_date  owner ticker  \
# 56                2020      2020-09-22       2020-08-17    NaN     --
# 57                2021      2021-03-23       2021-01-27   self     --
# 58                2021      2021-03-23       2021-02-08    NaN     --
# 59                2021      2021-03-23       2021-02-08   self     --
# 61                2021      2021-03-23       2021-02-19   self     --
# ...                ...             ...              ...    ...    ...
# 13916             2020      2020-03-15       2020-02-13  joint     --
# 13917             2020      2020-03-15       2020-02-13  joint     --
# 13918             2020      2020-03-15       2020-02-12  joint     --
# 13965             2020      2020-05-13       2020-04-29    NaN     --
# 14140             2020      2020-04-15       2020-03-28  joint     --
#
#                                       asset_description          type  \
# ...
